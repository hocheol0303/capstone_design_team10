# %%
import yaml

CONFIG_PATH = './configs/config_test.yaml'

with open(CONFIG_PATH, 'r') as f:
    config = yaml.safe_load(f)

# %%
config['training_datasets']
# Out:
# ['028_data', '030_data', '034_data', '045_data', '118_data', '999_data']
